# %%
import pandas as pd

# %%
newlabels = pd.read_json('labelled_nowiki.json')

# %%
newlabels.head(5)
# Out:
#                   ID                                              Quote  \
# 0  2015-02-09-001217  a proud transgender woman and for me to be vio...
# 1  2015-06-17-018173  I did feel I was gently being prodded into the...
# 2  2015-04-17-007557  Because my brother and sister are both gay and...
# 3  2015-03-09-028376  I think Sam died with a smile on his face, kno...
# 4  2015-03-10-009758  But my question with that [ is ] when you look...
#
#                  Speaker  numOccurrences               nationality
# 0                   none               1  United States of America
# 1  colin mathura-jeffree               2            United Kingdom
# 2          roseanne barr               1  United States of America
# 3         ingrid newkirk               4            United Kingdom
# 4             tra thomas               2  United States of America

# %%
newlabels[newlabels["nationality"]=="Canada"].head(20)
# Out:
#                      ID                                              Quote  \
# 93    2015-08-05-131988  With a national dialogue on racial equality, r...
# 210   2015-07-27-009075  Because the people of this country are underst...
# 228   2015-10-09-052456  I'm a mother, you know? And I am the mother of...
# 331   2015-12-10-138967  We realized that the brand is already one of t...
# 370   2015-01-05-009660  denial of marriage equality is a national prob...
# 454   2015-10-17-047240  quickie divorces, abortion, homosexual unions:...
# 755   2015-04-08-044144  It sounds to me like God doesn't hate the gays...
# 803   2015-04-08-033902  I was interested in the liberatory, activist a...
# 825   2015-10-02-045598  I'm 50 years old and when I was young you neve...
# 985   2015-03-25-108399  What really gets me is that he's taking up spa...
# 1293  2015-12-02-002532  a message that was less tilted toward minoriti...
# ...
