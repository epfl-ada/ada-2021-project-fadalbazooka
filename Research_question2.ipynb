# %% [markdown]
# ## Regression analysis on nationalities and genders

# %% [markdown]
# In the following analysis, the overall Sentiment score on gender norms is regressed on the top 6 most frequent nationalities of speakers as well as their gender.

# %%
import seaborn as sns 
from matplotlib import pyplot as plt 
import pandas as pd
import numpy as np
import nltk 
from collections import Counter
import statsmodels.formula.api as smf

# %%
df = pd.read_pickle('CleanDF.pkl')

# %%
list_countries = ['United States of America', 'United Kingdom', 'Australia','Canada','India','Ireland']
df = df[df.nationality.isin(list_countries)]
df.head(5)
# Out:
#            date_of_birth               nationality  gender  \
# Date
# 2015-11-01          1971  United States of America  female
# 2015-06-01          1971  United States of America  female
# 2015-04-01          1971  United States of America  female
# 2015-02-01          1971  United States of America  female
# 2015-01-01          1971  United States of America  female
#
#                            occupation           Speaker  \
# Date
# 2015-11-01  [LGBTIQ+ rights activist]  sarah kate ellis
# 2015-06-01  [LGBTIQ+ rights activist]  sarah kate ellis
# 2015-04-01  [LGBTIQ+ rights activist]  sarah kate ellis
# 2015-02-01  [LGBTIQ+ rights activist]  sarah kate ellis
# 2015-01-01  [LGBTIQ+ rights activist]  sarah kate ellis
#
#                                                         Quote  numOccurrences  \
# Date
# 2015-11-01  This loss is a wake-up call that despite remar...               2
# 2015-06-01  She didn't see it, she hadn't heard of it, she...               1
# 2015-04-01  As a journalist and anchor who reaches million...               1
# 2015-02-01  By empowering people to talk about their gende...               6
# 2015-01-01  By investing in this dangerous programming, TL...             133
#
#             quote_year  quote_month  Sentiment Sentiment Label
# Date
# 2015-11-01        2015           11    -0.8760        Negative
# 2015-06-01        2015            6     0.0387        Positive
# 2015-04-01        2015            4     0.4939        Positive
# 2015-02-01        2015            2     0.7003        Positive
# 2015-01-01        2015            1    -0.5610        Negative

# %%
df = df.drop(columns = ['occupation', 'Speaker','Quote', 'numOccurrences','quote_month', 'Sentiment Label', 'quote_year'])
df.head(5)
# Out:
#            date_of_birth               nationality  gender  Sentiment
# Date
# 2015-11-01          1971  United States of America  female    -0.8760
# 2015-06-01          1971  United States of America  female     0.0387
# 2015-04-01          1971  United States of America  female     0.4939
# 2015-02-01          1971  United States of America  female     0.7003
# 2015-01-01          1971  United States of America  female    -0.5610

# %%
df.loc[~df.gender.isin(["male", "female"]), "gender"] = "Other"

# %%
df = pd.concat([df, pd.get_dummies(df.gender).add_suffix("_onehot")], axis=1)  # one hot encoding
df = pd.concat([df, pd.get_dummies(df.nationality).add_suffix("_onehot")], axis=1)  # one hot encoding
df.head(5)
# Out:
#            date_of_birth               nationality  gender  Sentiment  \
# Date
# 2015-11-01          1971  United States of America  female    -0.8760
# 2015-06-01          1971  United States of America  female     0.0387
# 2015-04-01          1971  United States of America  female     0.4939
# 2015-02-01          1971  United States of America  female     0.7003
# 2015-01-01          1971  United States of America  female    -0.5610
#
#             Other_onehot  female_onehot  male_onehot  Australia_onehot  \
# Date
# 2015-11-01             0              1            0                 0
# 2015-06-01             0              1            0                 0
# 2015-04-01             0              1            0                 0
# 2015-02-01             0              1            0                 0
# 2015-01-01             0              1            0                 0
#
#             Canada_onehot  India_onehot  Ireland_onehot  \
# Date
# 2015-11-01              0             0               0
# 2015-06-01              0             0               0
# 2015-04-01              0             0               0
# 2015-02-01              0             0               0
# 2015-01-01              0             0               0
#
#             United Kingdom_onehot  United States of America_onehot
# Date
# 2015-11-01                      0                                1
# 2015-06-01                      0                                1
# 2015-04-01                      0                                1
# 2015-02-01                      0                                1
# 2015-01-01                      0                                1

# %%
df = df.rename(columns={"United Kingdom_onehot": "United_Kingdom_onehot"})

# %%
onehot_cols = [f"{col}_onehot" for col in df.columns]
features = onehot_cols + ["date_of_birth"]
y = df.Sentiment.to_numpy()

mod = smf.ols(formula='Sentiment ~ female_onehot + Other_onehot + Australia_onehot + Canada_onehot + India_onehot + Ireland_onehot + United_Kingdom_onehot',
              data = df) 

res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              Sentiment   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     13.80
# Date:                Sun, 12 Dec 2021   Prob (F-statistic):           5.61e-18
# Time:                        19:29:44   Log-Likelihood:                -79746.
# No. Observations:              100830   AIC:                         1.595e+05
# Df Residuals:                  100822   BIC:                         1.596e+05
# Df Model:                           7
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 0.1185      0.002     48.006      0.000       0.114       0.123
# female_onehot             0.0069      0.004      1.884      0.060      -0.000       0.014
# Other_onehot              0.0264      0.007      3.520      0.000       0.012       0.041
# Australia_onehot          0.0245      0.007      3.716      0.000       0.012       0.037
# Canada_onehot             0.0066      0.008      0.803      0.422      -0.010       0.023
# India_onehot              0.0832      0.011      7.786      0.000       0.062       0.104
# Ireland_onehot            0.0497      0.013      3.758      0.000       0.024       0.076
# United_Kingdom_onehot    -0.0002      0.005     -0.041      0.967      -0.010       0.009
# ==============================================================================
# Omnibus:                    18325.583   Durbin-Watson:                   1.786
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4673.779
# Skew:                          -0.234   Prob(JB):                         0.00
# Kurtosis:                       2.054   Cond. No.                         8.52
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Analysis

# %% [markdown]
# The group reference for the regression is composed of male speakers from the United States.

# %% [markdown]
# - We can see from the analysis that all the coefficients that are significant are positive, suggesting a higher sentiment score compared to the reference group.
# - The intercept is the mean for the reference group (American and male speakers) which is equal to 0.12
# - All other nationalities and genders have a significant higher sentiment on this topic compared to American male speakers.
